# %%
pip install deepface
# Out:
# Collecting deepface
#   Obtaining dependency information for deepface from https://files.pythonhosted.org/packages/ff/a1/0d342d7edbbcf04252afe135682e5985fea5f3fb40acd1caf1413241daed/deepface-0.0.80-py3-none-any.whl.metadata
#   Downloading deepface-0.0.80-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\tarun\anaconda3\lib\site-packages (from deepface) (1.24.3)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\tarun\anaconda3\lib\site-packages (from deepface) (2.0.3)
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\tarun\anaconda3\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\tarun\anaconda3\lib\site-packages (from deepface) (9.4.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\tarun\anaconda3\lib\site-packages (from deepface) (4.8.1.78)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\tarun\anaconda3\lib\site-packages (from deepface) (2.15.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\tarun\anaconda3\lib\site-packages (from deepface) (2.15.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\tarun\anaconda3\lib\site-packages (from deepface) (2.2.2)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#      -- ------------------------------------- 0.1/2.3 MB 3.6 MB/s eta 0:00:01
#      ------- -------------------------------- 0.5/2.3 MB 5.6 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.9/2.3 MB 7.2 MB/s eta 0:00:01
#      ------------------ --------------------- 1.0/2.3 MB 7.3 MB/s eta 0:00:01
#      ------------------ --------------------- 1.0/2.3 MB 7.3 MB/s eta 0:00:01
#      ------------------ --------------------- 1.0/2.3 MB 7.3 MB/s eta 0:00:01
#      -------------------- ------------------- 1.1/2.3 MB 3.5 MB/s eta 0:00:01
#      ------------------------ --------------- 1.4/2.3 MB 3.7 MB/s eta 0:00:01
#      ------------------------------ --------- 1.7/2.3 MB 4.0 MB/s eta 0:00:01
#      -------------------------------- ------- 1.9/2.3 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.3 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------- 2.3/2.3 MB 3.9 MB/s eta 0:00:00
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.13-py3-none-any.whl (16 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ---------------------------------------- 0.0/88.3 kB ? eta -:--:--
#      ---------------------------------------- 88.3/88.3 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gunicorn>=20.1.0 (from deepface)
#   Obtaining dependency information for gunicorn>=20.1.0 from https://files.pythonhosted.org/packages/0e/2a/c3a878eccb100ccddf45c50b6b8db8cf3301a6adede6e31d48e8531cab13/gunicorn-21.2.0-py3-none-any.whl.metadata
#   Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting Deprecated>=1.2.13 (from deepface)
#   Obtaining dependency information for Deprecated>=1.2.13 from https://files.pythonhosted.org/packages/20/8d/778b7d51b981a96554f29136cd59ca7880bf58094338085bcf2a979a0e6a/Deprecated-1.2.14-py2.py3-none-any.whl.metadata
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\tarun\anaconda3\lib\site-packages (from Deprecated>=1.2.13->deepface) (1.14.1)
# Requirement already satisfied: six in c:\users\tarun\anaconda3\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\tarun\anaconda3\lib\site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\tarun\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\tarun\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\tarun\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\tarun\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (8.0.4)
# Requirement already satisfied: filelock in c:\users\tarun\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.9.0)
# Requirement already satisfied: requests[socks] in c:\users\tarun\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\tarun\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: packaging in c:\users\tarun\anaconda3\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tarun\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tarun\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tarun\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (68.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.7.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\tarun\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.15.0)
# Requirement already satisfied: colorama in c:\users\tarun\anaconda3\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tarun\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tarun\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tarun\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tarun\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tarun\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tarun\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\tarun\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\tarun\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\tarun\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\tarun\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tarun\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\tarun\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tarun\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tarun\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tarun\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\tarun\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tarun\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tarun\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Downloading deepface-0.0.80-py3-none-any.whl (55 kB)
#    ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#    ---------------------------------------- 55.8/55.8 kB 2.8 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#    ---------------------------------------- 0.0/80.2 kB ? eta -:--:--
#    ---------------------------------------- 80.2/80.2 kB ? eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116947 sha256=6327ec0d9638c105c4ab187746b1ded0598f338394d78eb18936fa20db4ceec0
#   Stored in directory: c:\users\tarun\appdata\local\pip\cache\wheels\a7\ee\a5\19e91481be8bea594935d137578bfe77d6bf905e4595336f6b
# Successfully built fire
# Installing collected packages: gunicorn, fire, Deprecated, mtcnn, gdown, retina-face, deepface
# Successfully installed Deprecated-1.2.14 deepface-0.0.80 fire-0.5.0 gdown-4.7.1 gunicorn-21.2.0 mtcnn-0.1.1 retina-face-0.0.13
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from deepface import DeepFace

# %%
img=cv2.imread(r'C:\Users\tarun\Downloads\happy.jpeg')

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.54it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 14.539837837219238,
#    'disgust': 3.1737156212329865,
#    'fear': 15.887592732906342,
#    'happy': 0.456246268004179,
#    'sad': 42.649099230766296,
#    'surprise': 0.005431656245491467,
#    'neutral': 23.288074135780334},
#   'dominant_emotion': 'sad',
#   'region': {'x': 44, 'y': 4, 'w': 110, 'h': 110},
#   'face_confidence': 9.479904988256749,
#   'age': 19,
#   'gender': {'Woman': 68.47285628318787, 'Man': 31.52714967727661},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 0.5607545841485262,
#    'indian': 6.732198596000671,
#    'black': 0.24694092571735382,
#    'white': 24.63476061820984,
#    'middle eastern': 36.06818914413452,
#    'latino hispanic': 31.757161021232605},
#   'dominant_race': 'middle eastern'}]

# %%
type(predictions[0])
# Out:
# dict

# %%
print(predictions[0].get('dominant_emotion'))
# Out:
# sad

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(gray,1.1,4)

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX 
cv2.putText(img,
           predictions[0].get('dominant_emotion'),
           (0,50),
           font,1,
           (0,0,0),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
